# %%
import torch
import matplotlib.pyplot as plt

# %%
tensor = torch.load("topological_processed_data/faces/faces/4_identities/train/JohnLegend/5_proc0.pt")
plt.imshow(tensor.permute(1,2,0).numpy())

# %%
tensor = torch.load("topological_processed_data/faces/faces/4_identities/train/JohnLegend/5_proc1.pt")
plt.imshow(tensor.permute(1,2,0).numpy())

# %%
from topological_model import Model

# %%
model = Model()
output, feature_list = model(torch.randn(64,3,180,180))
# Out:
# torch.Size([64, 64, 45, 45])
# torch.Size([64, 128, 23, 23])
# torch.Size([64, 256, 12, 12])
# torch.Size([64, 512, 6, 6])

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("topological_output/losses.csv")
epochs = df["epoch"]

fig, axs = plt.subplots(2, 2, figsize=(14, 10))
blocks = [1, 2, 3, 4]
titles = ["Block 1", "Block 2", "Block 3", "Block 4"]

for idx, ax in enumerate(axs.flatten()):
    ax.plot(epochs, df[f"train_block{blocks[idx]}"], label="Train", color="blue")
    ax.plot(epochs, df[f"valid_block{blocks[idx]}"], label="Valid", color="orange")
    ax.plot(epochs, df[f"test_block{blocks[idx]}"], label="Test", color="green")
    ax.set_title(titles[idx])
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend()
    ax.grid(True)

plt.tight_layout()
#plt.savefig("topological_output/loss_subplots.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import pandas as pd
#       4 df = pd.read_csv("topological_output/losses.csv")
#       5 epochs = df["epoch"]
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 68.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 90.8 MB/s eta 0:00:00
# ...
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# ...

# %%
x = torch.load('topological_output/pred_pers_img_64_45_45.pt')[0].cpu().detach()
y = torch.load('topological_output/target_pers_img_64_45_45.pt')[0].cpu().detach()

# Plot first channel of x with colorbar
plt.imshow(x[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Predicted Persistence Image')
plt.show()

# Plot first channel of y with colorbar
plt.imshow(y[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Target Persistence Image')
plt.show()

# %%
x = torch.load('topological_output/pred_pers_img_128_23_23.pt')[0].cpu().detach()
y = torch.load('topological_output/target_pers_img_128_23_23.pt')[0].cpu().detach()

# Plot first channel of x with colorbar
plt.imshow(x[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Predicted Persistence Image')
plt.show()

# Plot first channel of y with colorbar
plt.imshow(y[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Target Persistence Image')
plt.show()

# %%
x = torch.load('topological_output/pred_pers_img_256_12_12.pt')[0].cpu().detach()
y = torch.load('topological_output/target_pers_img_256_12_12.pt')[0].cpu().detach()

# Plot first channel of x with colorbar
plt.imshow(x[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Predicted Persistence Image')
plt.show()

# Plot first channel of y with colorbar
plt.imshow(y[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Target Persistence Image')
plt.show()

# %%
x = torch.load('topological_output/pred_pers_img_512_6_6.pt')[0].cpu().detach()
y = torch.load('topological_output/target_pers_img_512_6_6.pt')[0].cpu().detach()

# Plot first channel of x with colorbar
plt.imshow(x[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Predicted Persistence Image')
plt.show()

# Plot first channel of y with colorbar
plt.imshow(y[0].numpy(), cmap='viridis')
plt.colorbar(label='Value')
plt.title('Target Persistence Image')
plt.show()
